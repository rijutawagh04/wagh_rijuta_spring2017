# %%
import nltk
from nltk.corpus import gutenberg
gut=gutenberg.fileids()
print(gut)
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']

# %%
# Calculating no of words in file 'austen-persuasion.txt'
import nltk
from nltk.corpus import gutenberg
words = nltk.corpus.gutenberg.words('austen-persuasion.txt')
print(words)
word_count=len(words)
print("The no of words in the file 'austen-persuasion.txt' is",word_count)
# Out:
# ['[', 'Persuasion', 'by', 'Jane', 'Austen', '1818', ...]
# The no of words in the file 'austen-persuasion.txt' is 98171

# %%
#Printing unique words in file 'austen-persuasion.txt'
uniq_words = set(words)
print("The no of words in the file 'austen-persuasion.txt' is", len(uniq_words))
# Out:
# The no of words in the file 'austen-persuasion.txt' is 6132

# %%
#Calculating frequency for each words
#Top 10 most frequent words with their frequency
from collections import Counter
freq_words= Counter(words)
#top_10_frequent=Counter(words).most_common(10)
print(freq_words)
print(top_10_frequent)
# Out:
# Counter({'securing': 1, 'Harry': 1, 'thrill': 1, 'whisper': 1, 'selfish': 1, 'danger': 1, 'lane': 1, '9': 1, 'came': 1, 'left': 1, 'implied': 1, 'instead': 1, 'contiguous': 1, 'tide': 1, 'gossip': 1, 'prejudice': 1, 'painful': 1, 'ailments': 1, '.--,': 1, 'below': 1, 'readiness': 1, 'threw': 1, 'ending': 1, 'refreshing': 1, 'singleness': 1, 'doubts': 1, 'there': 1, 'offend': 1, 'truly': 1, 'narratives': 1, 'consultations': 1, 'reserve': 1, 'appeared': 1, 'courting': 1, 'haste': 1, 'coloured': 1, 'lines': 1, 'surmounting': 1, 'fat': 1, 'list': 1, 'expressed': 1, 'reduce': 1, 'south': 1, 'gratified': 1, 'delicious': 1, 'frames': 1, 'Either': 1, 'wandering': 1, 'leisure': 1, 'dwell': 1, 'leaves': 1, 'did': 1, 'imaged': 1, 'pure': 1, 'cease': 1, 'consciously': 1, 'rock': 1, 'enforce': 1, 'rouse': 1, 'cost': 1, 'Rub': 1, 'Captains': 1, 'livery': 1, 'happy': 1, 'called': 1, 'patronised': 1, 'felt': 1, 'heaven': 1, 'tauntingly': 1, 'cavil': 1, 'whom': 1, 'Shirley': 1, 'undertook': 1, 'Thoug
# ...

# %%
counts = []
length_unique_words=len(uniq_words)
counts.append((length_unique_words,uniq_words))
counts.sort()
counts.reverse()
for i in range(min(10, len(counts))):
  length_unique_words, words = counts[i]
  print('%s %d' % (words,length_unique_words))
# Out:
# {'Harry', 'whisper', 'selfish', 'danger', '9', 'did', 'came', 'implied', 'cost', 'instead', 'contiguous', 'tide', 'gossip', 'ailments', 'timidity', 'Shepherd', 'below', 'readiness', 'threw', 'refreshing', 'doubts', 'consultations', 'reserve', 'courting', 'haste', 'lines', 'surmounting', 'fat', 'reduce', 'south', 'leisure', 'dwell', 'leaves', 'imaged', 'lightness', 'rouse', 'Rub', 'called', 'felt', 'heaven', 'compact', 'cavil', 'undertook', 'Though', 'discharging', 'grow', 'cupboards', 'than', 'glow', 'bursting', 'unquestionably', 'intelligible', 'food', 'canvass', 'Instead', 'cheerfullest', 'sharp', 'omitted', 'contrast', 'thirteen', 'exemplify', 'Dear', 'captures', 'calculations', 'box', 'nicety', 'interval', 'disengaged', 'terms', 'fine', 'Gowland', 'shame', 'honest', 'damp', 'plants', 'phoo', 'human', 'advised', 'reverse', 'pavement', 'suggestions', 'respects', 'House', 'surprise', 'precipitate', 'justness', 'barely', 'room', 'lamented', 'sitting', 'exchanged', 'ingenuity', 'sensi
# ...

# %%
top_10_frequent=Counter(words).most_common(10)
print(top_10_frequent)
# Out:
# [('securing', 1), ('Harry', 1), ('thrill', 1), ('whisper', 1), ('selfish', 1), ('danger', 1), ('lane', 1), ('9', 1), ('came', 1), ('left', 1)]

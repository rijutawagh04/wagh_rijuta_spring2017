# %%
import urllib.request
from bs4 import BeautifulSoup
import re
#import requests

# Ask user to enter URL
url = "http://www.nytimes.com/"

# Open txt document for output
txt = open('ctp_output.txt', 'w')

# Parse HTML of article, aka making soup
soup = BeautifulSoup(urllib.request.urlopen(url).read())

# Write the article title to the file    
title = soup.find("h1")
txt.write('\n' + "Title: " + title.string + '\n' + '\n')

# Write the article date to the file    
try:
    date = soup.find("span", {'class':'dateline'}).text
    txt.write("Date: " + str(date) + '\n' + '\n')
except:
    print("Could not find the date!")

# Write the article author to the file    
try:
    byline=soup.find("p", {'class':'byline-author'}).text
    txt.write("Author: " + str(byline) + '\n' + '\n')
except:
    print("Could not find the author!")

# Write the article location to the file    
regex = '<span class="location">(.+?)</span>'
pattern = re.compile(regex)
byline = re.findall(pattern,str(soup))
txt.write("Location: " + str(byline) + '\n' + '\n')

# retrieve all of the paragraph tags
with open('ctp_output.txt', 'w'):
    for tag in soup.find_all('p'):
        #txt.write(tag.text.encode('utf-8') + '\n' + '\n')

# Close txt file with new content added
        txt.close()
# Out:
# C:\Users\mahesh\Miniconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file C:\Users\mahesh\Miniconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))
# Could not find the date!
# Could not find the author!

# %%
#Next we use the get function in requests library to store data in a local variable called resp.
#This gives us everything in the form of a continuous string. We need to change this string into json format. So we use the loads function of json library to do that and store the json data into a variable called data.
import json, requests
from pprint import pprint

url = 'http://api.nytimes.com/svc/search/v2/articlesearch.json?q=new+york+times&page=2&sort=oldest&api-key=d94bedd25e2f4424881ce91cee408eb6'
resp = requests.get(url)
data = json.loads(resp.text)
pprint(data)
type(data)
# Out:
# {'copyright': 'Copyright (c) 2013 The New York Times Company.  All Rights '
#               'Reserved.',
#  'response': {'docs': [{'_id': '4fbfd24245c1498b0d004f86',
#                         'abstract': None,
#                         'blog': [],
#                         'byline': {'original': 'By Telegraph to The New-York '
#                                                'Times',
#                                    'person': [{'organization': '',
#                                                'rank': 1,
#                                                'role': 'reported'}]},
#                         'document_type': 'article',
#                         'headline': {'kicker': '1',
#                                      'main': 'LATEST INTELLIGENCE; From '
#                                              'Wahington--Population of South '
#                                              "Carolina--The President's "
#                                              'Health, &c.'},
#                         'keywords': [],
#                         'lead_paragraph': None,
#                         'multimedia': [],
#                         'news_desk': None,
#                         'print_page': '2',
#                         'pub_date': '1851-09-23T00:03:58Z',
#                         'section_name': None,
#                         'slideshow_credits': None,
#                         'snippet': None,
#                         'source': 'The New York Times',
#                         'subsection_name': None,
#                         'type_of_material': 'Article',
#                         'web_url': 'http://query.nytimes.com/gst/abstract.html?res=9407E0DE1431E13BBC4B51DFBF66838A649FDE',
#                         'word_count': 59},
#                        {'_id': '4fbfd24245c1498b0d004f79',
#                         'abstract': None,
#                         'blog': [],
#                         'byline': {'original': 'Correspondence of the New-York '
#                                                'Daily Times',
#                                    'person': [{'organization': '',
#                                                'rank': 1,
#                                                'role': 'reported'}]},
#                         'document_type': 'article',
#                         'headline': {'kicker': '1',
#                                      'main': "PHILADELPHIA.; Odd Fellows' "
#                                              'Parade--The Christiana Murder.'},
#                         'keywords': [],
#                         'lead_paragraph': "The Odd Fellows' parade this day, "
#                                           'on the occasion of the dedication '
#                                           'of their New Hall in Moyamensing, '
#                                           'was destroyed by the bad weather. '
#                                           'Several of the Lodges, however, '
#                                           'paraded and looked well. An order '
#                                           'for postponement was made in this '
#                                           'morning, until next Friday; but '
#                                           'afterwards revoked , not in time, '
#                                           'however, for many who had gone home '
#                                           'to re-assemble. The Hall was '
#                                           'dedicated with the usual '
#                                           'ceremonies.',
#                         'multimedia': [],
#                         'news_desk': None,
#                         'print_page': '4',
#                         'pub_date': '1851-09-23T00:03:58Z',
#                         'section_name': None,
#                         'slideshow_credits': None,
#                         'snippet': "The Odd Fellows' parade this day, on the "
#                                    'occasion of the dedication of their New '
#                                    'Hall in Moyamensing, was destroyed by the '
#                                    'bad weather. Several of the Lodges, '
#                                    'however, paraded and looked well. An order '
#                                    'for postponement was made in this morning, '
#                                    'un...',
#                         'source': 'The New York Times',
#                         'subsection_name': None,
#                         'type_of_material': 'Article',
#                         'web_url': 'http://query.nytimes.com/gst/abstract.html?res=9D01E0DE1431E13BBC4B51DFBF66838A649FDE',
#                         'word_count': 478},
#                        {'_id': '4fbfd24245c1498b0d004f88',
#                         'abstract': None,
#                         'blog': [],
#                         'byline': {'original': 'Correspondence of the New-York '
#                                                'Daily Times',
#                                    'person': [{'organization': '',
#                                                'rank': 1,
#                                                'role': 'reported'}]},
#                         'document_type': 'article',
#                         'headline': {'kicker': '1',
#                                      'main': 'Matters in Michigan.'},
#                         'keywords': [],
#                         'lead_paragraph': 'Michigan was never in a more '
#                                           'prosperous condition than at '
#                                           'present--never more inviting to the '
#                                           'farmer, the mechanic, the business '
#                                           'man; in short, to occupations of '
#                                           'all classes.',
#                         'multimedia': [],
#                         'news_desk': None,
#                         'print_page': '2',
#                         'pub_date': '1851-09-23T00:03:58Z',
#                         'section_name': None,
#                         'slideshow_credits': None,
#                         'snippet': 'Michigan was never in a more prosperous '
#                                    'condition than at present--never more '
#                                    'inviting to the farmer, the mechanic, the '
#                                    'business man; in short, to occupations of '
#                                    'all classes....',
#                         'source': 'The New York Times',
#                         'subsection_name': None,
#                         'type_of_material': 'Article',
#                         'web_url': 'http://query.nytimes.com/gst/abstract.html?res=9807E0DE1431E13BBC4B51DFBF66838A649FDE',
#                         'word_count': 449},
#                        {'_id': '4fbfd23e45c1498b0d004e02',
#                         'abstract': None,
#                         'blog': [],
#                         'byline': {'original': 'Correspondence of the New-York '
#                                                'Daily Times',
#                                    'person': [{'organization': '',
#                                                'rank': 1,
#                                                'role': 'reported'}]},
#                         'document_type': 'article',
#                         'headline': {'kicker': '1',
#                                      'main': 'The State Fair.; THIRD DAY.'},
#                         'keywords': [],
#                         'lead_paragraph': 'The arrangement of all the articles '
#                                           'entered for Exhibition at the Fair, '
#                                           'and the designation and completion '
#                                           'of the various committees for the '
#                                           'examination of them preparatory to '
#                                           'reports upon their comparative '
#                                           'excellencies, were finished '
#                                           'yesterday forenoon.',
#                         'multimedia': [],
#                         'news_desk': None,
#                         'print_page': '3',
#                         'pub_date': '1851-09-23T00:03:58Z',
#                         'section_name': None,
#                         'slideshow_credits': None,
#                         'snippet': 'The arrangement of all the articles '
#                                    'entered for Exhibition at the Fair, and '
#                                    'the designation and completion of the '
#                                    'various committees for the examination of '
#                                    'them preparatory to reports upon their '
#                                    'comparative excellencies, were finished '
#                                    'yesterday fo...',
#                         'source': 'The New York Times',
#                         'subsection_name': None,
#                         'type_of_material': 'Article',
#                         'web_url': 'http://query.nytimes.com/gst/abstract.html?res=9D06E0DE1431E13BBC4B51DFBF66838A649FDE',
#                         'word_count': 1193},
#                        {'_id': '4fbfd23f45c1498b0d004ef8',
#                         'abstract': 'His funeral',
#                         'blog': [],
#                         'byline': {'original': 'Correspondence of the New-York '
#                                                'Daily Times',
#                                    'person': [{'organization': '',
#                                                'rank': 1,
#                                                'role': 'reported'}]},
#                         'document_type': 'article',
#                         'headline': {'main': 'Funeral of James Fenimore '
#                                              'Cooper.'},
#                         'keywords': [{'name': 'persons',
#                                       'value': 'COOPER, J. FENNIMORE'}],
#                         'lead_paragraph': 'The remains of this distinguished '
#                                           'American citizen were this day '
#                                           'consigned to their final '
#                                           'resting-place. It seems but '
#                                           'yesterday he was walking our '
#                                           'streets, with his usual military '
#                                           'step, gentlemanly appearance and '
#                                           'erect figure, the picture of '
#                                           'health; and I can hardly realize '
#                                           'that he now sleeps with his '
#                                           'fathers. The funeral was appointed '
#                                           "at 3 1/2 o'clock.",
#                         'multimedia': [],
#                         'news_desk': None,
#                         'print_page': '4',
#                         'pub_date': '1851-09-23T00:03:58Z',
#                         'section_name': None,
#                         'slideshow_credits': None,
#                         'snippet': 'The remains of this distinguished American '
#                                    'citizen were this day consigned to their '
#                                    'final resting-place. It seems but '
#                                    'yesterday he was walking our streets, with '
#                                    'his usual military step, gentlemanly '
#                                    'appearance and erect figure, the picture '
#                                    'of healt...',
#                         'source': 'The New York Times',
#                         'subsection_name': None,
#                         'type_of_material': 'Article',
#                         'web_url': 'http://query.nytimes.com/gst/abstract.html?res=9506E0DE1431E13BBC4B51DFBF66838A649FDE',
#                         'word_count': 880},
#                        {'_id': '4fbfd23f45c1498b0d004e1d',
#                         'abstract': None,
#                         'blog': [],
#                         'byline': {'original': 'Correspondence of the New-York '
#                                                'Daily TimesR.U',
#                                    'person': [{'organization': '',
#                                                'rank': 1,
#                                                'role': 'reported'}]},
#                         'document_type': 'article',
#                         'headline': {'kicker': '1',
#                                      'main': 'Lumber Trade of Michigan.'},
#                         'keywords': [],
#                         'lead_paragraph': None,
#                         'multimedia': [],
#                         'news_desk': None,
#                         'print_page': '4',
#                         'pub_date': '1851-09-24T00:03:58Z',
#                         'section_name': None,
#                         'slideshow_credits': None,
#                         'snippet': None,
#                         'source': 'The New York Times',
#                         'subsection_name': None,
#                         'type_of_material': 'Article',
#                         'web_url': 'http://query.nytimes.com/gst/abstract.html?res=9E02E4D8173DE537A75757C2A96F9C946092D7CF',
#                         'word_count': 277},
#                        {'_id': '4fbfd24245c1498b0d005093',
#                         'abstract': 'Explosion of the James Jackson',
#                         'blog': [],
#                         'byline': None,
#                         'document_type': 'article',
#                         'headline': {'main': 'LATEST INTELLIGENCE; Dreadful '
#                                              'Steamboat Accident--Thirty-five '
#                                              'Persons Killed and Wounded. The '
#                                              'Great Telegraph Case--Morse '
#                                              'versus Bain. From '
#                                              'Washington--Extension of the '
#                                              'Capitol-- The Texas Debt. '
#                                              'Portland and Halifax Railway. '
#                                              'Items from South. The Canal '
#                                              'Breaks. Navigation of the Ohio.'},
#                         'keywords': [{'name': 'subject',
#                                       'value': 'STEAM BOAT ACCIDENTS'}],
#                         'lead_paragraph': 'The steamer James Jackson, explodad '
#                                           'yesterday, just as she was leaving '
#                                           'Shawneetown, in Illinois. A '
#                                           'dreadful and heart-rending scene '
#                                           'ensued. Thirtyfive persons were '
#                                           'killed and wounded. The shrieks of '
#                                           'the wounded and dying caused a '
#                                           'thrill of horror in every breast. '
#                                           'We received the sad news here this '
#                                           'morning by the steamer Summit. The '
#                                           'names of the sufferers, as far as '
#                                           'we have been able to learn, are '
#                                           'as...',
#                         'multimedia': [],
#                         'news_desk': None,
#                         'print_page': '2',
#                         'pub_date': '1851-09-24T00:03:58Z',
#                         'section_name': None,
#                         'slideshow_credits': None,
#                         'snippet': 'The steamer James Jackson, explodad '
#                                    'yesterday, just as she was leaving '
#                                    'Shawneetown, in Illinois. A dreadful and '
#                                    'heart-rending scene ensued. Thirtyfive '
#                                    'persons were killed and wounded. The '
#                                    'shrieks of the wounded and dying caused a '
#                                    'thrill of horror ...',
#                         'source': 'The New York Times',
#                         'subsection_name': None,
#                         'type_of_material': 'Article',
#                         'web_url': 'http://query.nytimes.com/gst/abstract.html?res=9E05E5D8173DE537A75757C2A96F9C946092D7CF',
#                         'word_count': 1097},
#                        {'_id': '4fbfd24245c1498b0d00508e',
#                         'abstract': 'Speech at Detroit in the Conspiracy Case',
#                         'blog': [],
#                         'byline': {'original': 'Correspondence of the New-York '
#                                                'Daily Times.OKEMOS',
#                                    'person': [{'organization': '',
#                                                'rank': 1,
#                                                'role': 'reported'}]},
#                         'document_type': 'article',
#                         'headline': {'main': 'MICHIGAN.; Railroad Conspiracy '
#                                              "Trials--Seward's Speech-- Gen. "
#                                              'Scott--Gen. Cass--Travel--Canada '
#                                              'Road --Business at '
#                                              'Detroit--Rapid Settlement on '
#                                              'Lake Superior.'},
#                         'keywords': [{'name': 'persons',
#                                       'value': 'SEWARD W.H.'}],
#                         'lead_paragraph': 'Our opponents are in a . Their '
#                                           'Conven tion. comes off on next '
#                                           'week. a2 Governor is to be 7. '
#                                           'Robert , the late member of '
#                                           '(Congress from this State, is a '
#                                           'Freesoilcr; so aro mne-half of the '
#                                           'Loco party in the State. is a to go '
#                                           'before their convention. Barry to '
#                                           'be a Comprotnisc man. He, too, as a '
#                                           'candidate for reelection. The '
#                                           '[Cass] section arc 7tard at work to '
#                                           '.the Convention against 3fac, as '
#                                           "they sa.y, it w211 injure Cass's "
#                                           'prospects a>, the South, if he is '
#                                           'nominated. Whether Mac or Cass hill '
#                                           ',tt)e day it remains to lie seen. '
#                                           'One thing, however, is , no Loco '
#                                           'can be elected, unless Ire '
#                                           'satisfies the Barnburners here, '
#                                           "flail ho' is with thern. Unless "
#                                           'there is somo compromise in their '
#                                           'party, among themselves, Gen. Cass '
#                                           'will;not receive the votes of the '
#                                           'Loco delegates ut Baltimore, from '
#                                           '3.',
#                         'multimedia': [],
#                         'news_desk': None,
#                         'print_page': '4',
#                         'pub_date': '1851-09-24T00:03:58Z',
#                         'section_name': None,
#                         'slideshow_credits': None,
#                         'snippet': 'Our opponents are in a . Their Conven '
#                                    'tion. comes off on next week. a2 Governor '
#                                    'is to be 7. Robert , the late member of '
#                                    '(Congress from this State, is a '
#                                    'Freesoilcr; so aro mne-half of the Loco '
#                                    'party in the State.  is a  to go before '
#                                    'their conventio...',
#                         'source': 'The New York Times',
#                         'subsection_name': None,
#                         'type_of_material': 'Article',
#                         'web_url': 'http://query.nytimes.com/gst/abstract.html?res=9E03E4D8173DE537A75757C2A96F9C946092D7CF',
#                         'word_count': 776},
#                        {'_id': '4fbfd23f45c1498b0d004efb',
#                         'abstract': "Mr Clay's tribute to",
#                         'blog': [],
#                         'byline': None,
#                         'document_type': 'article',
#                         'headline': {'main': 'An Appeal to the American '
#                                              'Public, in Behalf of the Very '
#                                              'Rev. Father Mathew.'},
#                         'keywords': [{'name': 'persons',
#                                       'value': 'CLAY, HENRY'},
#                                      {'name': 'persons',
#                                       'value': 'MATTHEW. THEOBALD'},
#                                      {'name': 'persons',
#                                       'value': 'MATTHEW. THEOBALD'}],
#                         'lead_paragraph': 'One of the greatest benefactors of '
#                                           'the human family that out favored '
#                                           'country has ever entertained, is '
#                                           'about to leave us and to return to '
#                                           'his native land to die, after a '
#                                           'life devoted to the poor, the '
#                                           'afflicted and the friendless.',
#                         'multimedia': [],
#                         'news_desk': None,
#                         'print_page': '2',
#                         'pub_date': '1851-09-25T00:03:58Z',
#                         'section_name': None,
#                         'slideshow_credits': None,
#                         'snippet': 'One of the greatest benefactors of the '
#                                    'human family that out favored country has '
#                                    'ever entertained, is about to leave us and '
#                                    'to return to his native land to die, after '
#                                    'a life devoted to the poor, the afflicted '
#                                    'and the friendless....',
#                         'source': 'The New York Times',
#                         'subsection_name': None,
#                         'type_of_material': 'Article',
#                         'web_url': 'http://query.nytimes.com/gst/abstract.html?res=9E0DE0DE1431E13BBC4D51DFBF66838A649FDE',
#                         'word_count': 1463},
#                        {'_id': '4fbfd24245c1498b0d004f9d',
#                         'abstract': None,
#                         'blog': [],
#                         'byline': None,
#                         'document_type': 'article',
#                         'headline': {'kicker': '1',
#                                      'main': 'NEW PUBLICATONS.; THE HISTORY OF '
#                                              'THE RESTORATION OF MONARCHY IN '
#                                              'FRANCE. By ALPHONSE DE '
#                                              'LAMARTINE. New-York: Harper & '
#                                              'Brothers.'},
#                         'keywords': [],
#                         'lead_paragraph': 'In the course of the thirty years '
#                                           'which have elapsed since his '
#                                           'Meditations Poctiques were given to '
#                                           'the world, M. LAMARTINE, through a '
#                                           'variety of chances and changes, has '
#                                           'been steadily gravitating toward '
#                                           'his appropriate sphere in the '
#                                           '"universe of letters."',
#                         'multimedia': [],
#                         'news_desk': None,
#                         'print_page': '1',
#                         'pub_date': '1851-09-25T00:03:58Z',
#                         'section_name': None,
#                         'slideshow_credits': None,
#                         'snippet': 'In the course of the thirty years which '
#                                    'have elapsed since his Meditations '
#                                    'Poctiques were given to the world, M. '
#                                    'LAMARTINE, through a variety of chances '
#                                    'and changes, has been steadily gravitating '
#                                    'toward his appropriate sphere in the '
#                                    '"universe of l...',
#                         'source': 'The New York Times',
#                         'subsection_name': None,
#                         'type_of_material': 'Review',
#                         'web_url': 'http://query.nytimes.com/gst/abstract.html?res=9B03E0DE1431E13BBC4D51DFBF66838A649FDE',
#                         'word_count': 2588}],
#               'meta': {'hits': 3740620, 'offset': 20, 'time': 478}},
#  'status': 'OK'}
# dict

# %%
for key in data:

    print(key)
    #pprint(data["response"])
    pprint(data["response"]["docs"][0])
# Out:
# response
# {'_id': '4fbfd24245c1498b0d004f86',
#  'abstract': None,
#  'blog': [],
#  'byline': {'original': 'By Telegraph to The New-York Times',
#             'person': [{'organization': '', 'rank': 1, 'role': 'reported'}]},
#  'document_type': 'article',
#  'headline': {'kicker': '1',
#               'main': 'LATEST INTELLIGENCE; From Wahington--Population of '
#                       "South Carolina--The President's Health, &c."},
#  'keywords': [],
#  'lead_paragraph': None,
#  'multimedia': [],
#  'news_desk': None,
#  'print_page': '2',
#  'pub_date': '1851-09-23T00:03:58Z',
#  'section_name': None,
#  'slideshow_credits': None,
#  'snippet': None,
#  'source': 'The New York Times',
#  'subsection_name': None,
#  'type_of_material': 'Article',
#  'web_url': 'http://query.nytimes.com/gst/abstract.html?res=9407E0DE1431E13BBC4B51DFBF66838A649FDE',
#  'word_count': 59}
# status
# {'_id': '4fbfd24245c1498b0d004f86',
#  'abstract': None,
#  'blog': [],
#  'byline': {'original': 'By Telegraph to The New-York Times',
#             'person': [{'organization': '', 'rank': 1, 'role': 'reported'}]},
#  'document_type': 'article',
#  'headline': {'kicker': '1',
#               'main': 'LATEST INTELLIGENCE; From Wahington--Population of '
#                       "South Carolina--The President's Health, &c."},
#  'keywords': [],
#  'lead_paragraph': None,
#  'multimedia': [],
#  'news_desk': None,
#  'print_page': '2',
#  'pub_date': '1851-09-23T00:03:58Z',
#  'section_name': None,
#  'slideshow_credits': None,
#  'snippet': None,
#  'source': 'The New York Times',
#  'subsection_name': None,
#  'type_of_material': 'Article',
#  'web_url': 'http://query.nytimes.com/gst/abstract.html?res=9407E0DE1431E13BBC4B51DFBF66838A649FDE',
#  'word_count': 59}
# copyright
# {'_id': '4fbfd24245c1498b0d004f86',
#  'abstract': None,
#  'blog': [],
#  'byline': {'original': 'By Telegraph to The New-York Times',
#             'person': [{'organization': '', 'rank': 1, 'role': 'reported'}]},
#  'document_type': 'article',
#  'headline': {'kicker': '1',
#               'main': 'LATEST INTELLIGENCE; From Wahington--Population of '
#                       "South Carolina--The President's Health, &c."},
#  'keywords': [],
#  'lead_paragraph': None,
#  'multimedia': [],
#  'news_desk': None,
#  'print_page': '2',
#  'pub_date': '1851-09-23T00:03:58Z',
#  'section_name': None,
#  'slideshow_credits': None,
#  'snippet': None,
#  'source': 'The New York Times',
#  'subsection_name': None,
#  'type_of_material': 'Article',
#  'web_url': 'http://query.nytimes.com/gst/abstract.html?res=9407E0DE1431E13BBC4B51DFBF66838A649FDE',
#  'word_count': 59}

# %%
for key in data["response"]["docs"]:

    pprint(key["headline"]["main"])
# Out:
# ('LATEST INTELLIGENCE; From Wahington--Population of South Carolina--The '
#  "President's Health, &c.")
# "PHILADELPHIA.; Odd Fellows' Parade--The Christiana Murder."
# 'Matters in Michigan.'
# 'The State Fair.; THIRD DAY.'
# 'Funeral of James Fenimore Cooper.'
# 'Lumber Trade of Michigan.'
# ('LATEST INTELLIGENCE; Dreadful Steamboat Accident--Thirty-five Persons Killed '
#  'and Wounded. The Great Telegraph Case--Morse versus Bain. From '
#  'Washington--Extension of the Capitol-- The Texas Debt. Portland and Halifax '
#  'Railway. Items from South. The Canal Breaks. Navigation of the Ohio.')
# ("MICHIGAN.; Railroad Conspiracy Trials--Seward's Speech-- Gen. Scott--Gen. "
#  'Cass--Travel--Canada Road --Business at Detroit--Rapid Settlement on Lake '
#  'Superior.')
# 'An Appeal to the American Public, in Behalf of the Very Rev. Father Mathew.'
# ('NEW PUBLICATONS.; THE HISTORY OF THE RESTORATION OF MONARCHY IN FRANCE. By '
#  'ALPHONSE DE LAMARTINE. New-York: Harper & Brothers.')

# %%
query = "Presidential"

url = "http://api.nytimes.com/svc/search/v2/articlesearch.json?q=&#8221; + query + “&page=2&sort=oldest&api-key=d94bedd25e2f4424881ce91cee408eb6"
for key in data["response"]["docs"]:
    .

    pprint(key["headline"]["main"])
# Out:
# ('LATEST INTELLIGENCE; From Wahington--Population of South Carolina--The '
#  "President's Health, &c.")
# "PHILADELPHIA.; Odd Fellows' Parade--The Christiana Murder."
# 'Matters in Michigan.'
# 'The State Fair.; THIRD DAY.'
# 'Funeral of James Fenimore Cooper.'
# 'Lumber Trade of Michigan.'
# ('LATEST INTELLIGENCE; Dreadful Steamboat Accident--Thirty-five Persons Killed '
#  'and Wounded. The Great Telegraph Case--Morse versus Bain. From '
#  'Washington--Extension of the Capitol-- The Texas Debt. Portland and Halifax '
#  'Railway. Items from South. The Canal Breaks. Navigation of the Ohio.')
# ("MICHIGAN.; Railroad Conspiracy Trials--Seward's Speech-- Gen. Scott--Gen. "
#  'Cass--Travel--Canada Road --Business at Detroit--Rapid Settlement on Lake '
#  'Superior.')
# 'An Appeal to the American Public, in Behalf of the Very Rev. Father Mathew.'
# ('NEW PUBLICATONS.; THE HISTORY OF THE RESTORATION OF MONARCHY IN FRANCE. By '
#  'ALPHONSE DE LAMARTINE. New-York: Harper & Brothers.')

# %%
with open('json.txt','w') as myfile:
    json.dump(data,myfile)

# %%
import os
nyt_article_search__key = os.getenv('auth_key')
print(nyt_article_search__key)
import requests
import urllib.parse
import json
url = 'http://api.nytimes.com/svc/search/v2/articlesearch.json?q=new+york+times&page=41&sort=newest&api-key=33be9c525b7d4220a3c52a788d9d68d6'
response = requests.get(url).json()
with open('response_1.json', 'w') as fp:
    json.dump(response, fp)
# Out:
# None

# %%
import requests
import urllib.parse
import json
api_key='33be9c525b7d4220a3c52a788d9d68d6'
date = 20121201
page = 1

# %%
url = "http://api.nytimes.com/svc/search/v2/articlesearch.json?begin_date=" + str(date) + "&end_date=" + str(date) + "&page=" + str(page) + "&api-key=" + str(api_key)
response = requests.get(url).json()
with open(str(date) + '_article_' + str(page)+ '.json', 'w') as fp:
    json.dump(response, fp)
    page += 1
    date += 1
    print(page)
# Out:
# 13

# %%
import os, json
import pandas as pd
import shutil
path_to_json = 'C:\\Users\\mahesh\\Desktop\\Data analysis spring 2017\\Data_Analysis_Assignments\\wagh_rijuta_spring2017\\Midterm\\Articlejson'
path_file= 'C:\\Users\\mahesh\\Desktop\\Data analysis spring 2017\\Data_Analysis_Assignments\\wagh_rijuta_spring2017\\Midterm\\ArticleResult'
#path = '\\users\\kruts\\Midterm2Result'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
#print (json_files) 

def ensure_dir(path_file):
    #directory = os.path.dirname(path_file)
    #print(path_file)
    if not os.path.exists(path_file):
        os.makedirs(path_file)
        #print(path_file)
    #return directory

# %%
import json
import glob
file = "*.json"

from shutil import copy
for js in glob.glob(os.path.join(path_to_json,file)):
            json_file_read = json.loads(open(js).read())
            for key,value in json_file_read.items():
                #print(key)
                if key == "response": # creation of folders
                    
                    meta = value.get('meta')
                    #print(meta)
                    docs = value.get('docs')
                    for article in docs :
                        sect_name = article.get('section_name')
                        sect_name = str(sect_name).replace("/"," ")
                        sect_name = str(sect_name).replace(":"," ")
                        #hits = meta.get('hits')
                        path = os.path.join(path_file + '\\' + str(sect_name))
                        #path = os.path.join(path + '/' + hits)
                        #print(path)
                        ensure_dir(path)
                        copy(js,path)

# %%
#Collecting  data using Archive API
import requests
import urllib.parse
import json
api_key='33be9c525b7d4220a3c52a788d9d68d6'
date = 20121201
page = 1

# %%
url = "https://api.nytimes.com/svc/archive/v1/2016/1.json?begin_date=" + str(date) + "&end_date=" + str(date) + "&page=" + str(page) + "&api-key=" + str(api_key)
response = requests.get(url).json()
with open(str(date) + '_archive_' + str(page)+ '.json', 'w') as fp:
    json.dump(response, fp)
    page += 1
    date += 1
    print(page)

# %%
import os, json
import pandas as pd
import shutil
path_to_json = 'C:\\Users\\mahesh\\Desktop\\Data analysis spring 2017\\Data_Analysis_Assignments\\wagh_rijuta_spring2017\\Midterm\\ArchiveJson'
path_file= 'C:\\Users\\mahesh\\Desktop\\Data analysis spring 2017\\Data_Analysis_Assignments\\wagh_rijuta_spring2017\\Midterm\\ArchiveResult'
#path = '\\users\\kruts\\Midterm2Result'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
#print (json_files) 

def ensure_dir(path_file):
    #directory = os.path.dirname(path_file)
    #print(path_file)
    if not os.path.exists(path_file):
        os.makedirs(path_file)
        #print(path_file)
    #return directory

# %%
import json
import glob
file = "*.json"

from shutil import copy
for js in glob.glob(os.path.join(path_to_json,file)):
            json_file_read = json.loads(open(js).read())
            for key,value in json_file_read.items():
                #print(key)
                if key == "response": # creation of folders
                    
                    meta = value.get('meta')
                    #print(meta)
                    docs = value.get('docs')
                    for article in docs :
                        sect_name = article.get('section_name')
                        sect_name = str(sect_name).replace("/"," ")
                        sect_name = str(sect_name).replace(":"," ")
                        #hits = meta.get('hits')
                        path = os.path.join(path_file + '\\' + str(sect_name))
                        #path = os.path.join(path + '/' + hits)
                        #print(path)
                        ensure_dir(path)
                        copy(js,path)

# %%
import re
import datetime
from datetime import datetime
import datetime
import os
import json
c=0
b=0

jpath = 'C:\\Users\\mahesh\\Desktop\\Data analysis spring 2017\\Data_Analysis_Assignments\\wagh_rijuta_spring2017\\Midterm\\ArchiveResult'
        
for root, dirs, files in os.walk(jpath):
        
            for f in files:
                if f.endswith('.json'):
                    with open(os.path.join(root,f), 'r', encoding='utf-8', errors="ignore") as json_file:      
                        artdata=json.load(json_file)
#                         print(artdata.kesys)
                        
                        
                       
                        if 'pub_date' in artdata.keys():
                            match= re.search(r'\d{4}-\d{2}-\d{2}', artdata['pub_date'])

                            date = datetime.datetime.strptime(match.group(), '%Y-%m-%d').date()

                            for i in range(0,len(artdata['keywords'])):
                                    if 'glocation' in artdata['keywords'][i]['name']:
                                        if 'boston' in artdata['keywords'][i]['value'].lower():
                                                try:
                                                    if 'terror' in artdata['lead_paragraph'].lower():
                                                        c+=1
                                                    if 'shooting' in artdata['lead_paragraph'].lower():
                                                        c+=1
                                                    if 'murder' in artdata['lead_paragraph'].lower():
                                                        c+=1
                                                except AttributeError:
                                                    pass
                                                
                                        if 'california' in artdata['keywords'][i]['value'].lower():
                                                try:
                                                    if 'terror' in artdata['lead_paragraph'].lower():
                                                        b+=1
                                                    if 'shooting' in artdata['lead_paragraph'].lower():
                                                        b+=1
                                                    if 'murder' in artdata['lead_paragraph'].lower():
                                                        b+=1
                                                except AttributeError:
                                                    pass
                                                    

print( 'Number of Shootings,crime and murder in boston is' ,+c)
print( 'Number of Shootings,crime and murder in california is' ,+b)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-11-87b30af28739> in <module>()
#      15                 if f.endswith('.json'):
#      16                     with open(os.path.join(root,f), 'r', encoding='utf-8', errors="ignore") as json_file:
# ---> 17                         artdata=json.load(json_file)
#      18 #                         print(artdata.kesys)
#      19
#
# C:\Users\mahesh\Miniconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     266         cls=cls, object_hook=object_hook,
#     267         parse_float=parse_float, parse_int=parse_int,
# --> 268         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     269
#     270
#
# C:\Users\mahesh\Miniconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     317             parse_int is None and parse_float is None and
#     318             parse_constant is None and object_pairs_hook is None and not kw):
# --> 319         return _default_decoder.decode(s)
#     320     if cls is None:
#     321         cls = JSONDecoder
#
# C:\Users\mahesh\Miniconda3\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# C:\Users\mahesh\Miniconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
